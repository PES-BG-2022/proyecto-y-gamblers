# %% [markdown]
# ## Simulación Monte Carlo para Blackjack

# %% [markdown]
# - Banco de Guatemala
# - Programa de Estudios Superiores -PES-
# - 2022
# - Luis González
# - Javier Monroy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creamos el deck, lo barajeamos y creamos el shoe para el juego

# %%
#Creamos todas las cartas y su valor en el juego
shoe=np.array([1,1,1,1])
two = np.array([2,2,2,2])
three = np.array([3,3,3,3])
four = np.array([4,4,4,4])
five = np.array([5,5,5,5])
six = np.array([6,6,6,6])
seven = np.array([7,7,7,7])
eight = np.array([8,8,8,8])
nine = np.array([9,9,9,9])
ten = np.array([10,10,10,10])
j = np.array([10,10,10,10])
q = np.array([10,10,10,10])
k = np.array([10,10,10,10])




#Lista que solo sirve para iterarla y formar el deck
total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)

#Formamos el deck ordenado
for i in total_faces:
    shoe = np.hstack((shoe,i))

#print(f"El deck es: {shoe}")
#Barajeamos el deck para para convertirlo en shoe
np.random.shuffle(shoe)

print(f"El shoe es: {shoe}")

#print(type(shoe))
# Out:
# El shoe es: [10  4  9 10 10  7  2  1  3  5  2  6  9  8  3 10 10  7  6 10 10  1  4  9
#  10 10  9 10  3 10  6  4  4  8  5  1 10  5  5  1  8  2 10 10  2 10  3  6
#   7  8  7 10]

# %% [markdown]
# Ya con el shoe en la mesa, repartimos las cartas

# %%
#Mientras que el shoe no este vacío, entonces que se repartan las cartas

player_hand=np.array([0])
dealer_hand=np.array([])

for i in shoe:
    print(i)

# %%
def blackjack_game(decks:int, players=1):    

    shoe=np.full(decks*4,1)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    print(shoe)
    while (shoe.size>0):
        print("********************************************")
        print(f"El shoe tiene: {shoe.size} cartas")
        
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {card}")
        
        if (player_hand.size<=2):
            player_hand=np.append(player_hand, shoe[0])
        shoe = np.delete(shoe,0)        
        
        if (dealer_hand.size<=2):
            dealer_hand=np.append(dealer_hand, shoe[0])
        shoe = np.delete(shoe,0)

        #while (np.sum(dealer_hand)<17):
            #card = int(shoe[0])
            #dealer_hand=np.append(dealer_hand, shoe[0])
        #shoe = np.delete(shoe,0)

        #while (np.sum(dealer_hand)<17):
            #dealer_hand=np.append(dealer_hand, shoe[0])
            #shoe = np.delete(shoe,0)
        print(f"La suma del dealer es: {np.sum(dealer_hand)}")
        
        print(f"El player hand es de: {player_hand}")
        print(f"El dealer hand es de: {dealer_hand}")        
    else:
        print("¡Se acabó el shoe!")
    return True
blackjack_game(1)
# Out:
# [ 4  9  5  8  6 10  4  6  9  5 10  2 10  9 10  6  1  8 10  3  1  1 10  8
#   3 10  6 10 10 10  2 10 10  7  1  5  7  8 10  9  2  4  2 10  4 10  5  3
#   7 10  7  3]
# ********************************************
# El shoe tiene: 52 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 9
# El player hand es de: [0 4]
# El dealer hand es de: [0 9]
# ********************************************
# El shoe tiene: 50 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 48 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 46 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 44 cartas
# La carta que acaba de salir es: 9
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 42 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 40 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 38 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 36 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 34 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 32 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 30 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 28 cartas
# La carta que acaba de salir es: 3
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 26 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 24 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 22 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 20 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 18 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 16 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 14 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 12 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 10 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 8 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 6 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 4 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ********************************************
# El shoe tiene: 2 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 17
# El player hand es de: [0 4 5]
# El dealer hand es de: [0 9 8]
# ¡Se acabó el shoe!
# True

# %%
def blackjack_game(decks:int, players=1):    

    shoe=np.full(decks*4,1)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    print(shoe)
    while (shoe.size>0):
        print("********************************************")
        print(f"El shoe tiene: {shoe.size} cartas")
        
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {card}")
        
        while (player_hand.size<=2):
            player_hand=np.append(player_hand, card)
            break
        shoe = np.delete(shoe,0)        

        

        #if (player_hand.size<=2):
         #   player_hand=np.append(player_hand, shoe[0])
        #shoe = np.delete(shoe,0)        
        

        #if (np.sum(dealer_hand)<17):
            #dealer_hand=np.append(dealer_hand, shoe[0])
        #shoe = np.delete(shoe,0)

        print(f"La suma del dealer es: {np.sum(dealer_hand)}")
        
        print(f"El player hand es de: {player_hand}")
        print(f"El dealer hand es de: {dealer_hand}")        
    else:
        print("¡Se acabó el shoe!")
    return True
blackjack_game(1)
# Out:
# [10  1  3  1  4  7  3  2  7  5  2  5  8 10  6  9 10  6 10  8  2  5  4  5
#   4 10  6  4  8  8 10 10  9  7  1 10 10  6  3  7  1 10  3  9  9  2 10 10
#  10 10 10 10]
# ********************************************
# El shoe tiene: 52 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 51 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 50 cartas
# La carta que acaba de salir es: 3
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 49 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 48 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 47 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 46 cartas
# La carta que acaba de salir es: 3
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 45 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 44 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 43 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 42 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 41 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 40 cartas
# La carta que acaba de salir es: 8
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 39 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 38 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 37 cartas
# La carta que acaba de salir es: 9
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 36 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 35 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 34 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 33 cartas
# La carta que acaba de salir es: 8
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 32 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 31 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 30 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 29 cartas
# La carta que acaba de salir es: 5
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 28 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 27 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 26 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 25 cartas
# La carta que acaba de salir es: 4
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 24 cartas
# La carta que acaba de salir es: 8
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 23 cartas
# La carta que acaba de salir es: 8
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 22 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 21 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 20 cartas
# La carta que acaba de salir es: 9
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 19 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 18 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 17 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 16 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 15 cartas
# La carta que acaba de salir es: 6
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 14 cartas
# La carta que acaba de salir es: 3
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 13 cartas
# La carta que acaba de salir es: 7
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 12 cartas
# La carta que acaba de salir es: 1
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 11 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 10 cartas
# La carta que acaba de salir es: 3
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 9 cartas
# La carta que acaba de salir es: 9
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 8 cartas
# La carta que acaba de salir es: 9
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 7 cartas
# La carta que acaba de salir es: 2
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 6 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 5 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 4 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 3 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 2 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ********************************************
# El shoe tiene: 1 cartas
# La carta que acaba de salir es: 10
# La suma del dealer es: 0
# El player hand es de: [ 0 10  1]
# El dealer hand es de: [0]
# ¡Se acabó el shoe!
# True

# %% [markdown]
# ## COMPILA 1

# %%
def blackjack_game(decks:int, players=1):    
    d=dict()
    profit_dealer=0
    profit_player=0
    shoe=np.full(decks*4,1)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    print(shoe)
    while (shoe.size>5):
        print("********************************************")
        print(f"El shoe tiene: {shoe.size} cartas")
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {int(shoe[0])}")
        #Se le da las 2 cartas inciales al jugador
        if (player_hand.size<=2):
            player_hand=np.append(player_hand, shoe[0])
        print(f"El player hand es de: {player_hand}")
        shoe = np.delete(shoe,0)        
        
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {card}")
        #Se le da las 2 cartas iniciales al dealer
        if (dealer_hand.size<=2):
            dealer_hand=np.append(dealer_hand, shoe[0])
        print(f"El dealer hand es de: {dealer_hand}")
        shoe = np.delete(shoe,0)
        #ee   
        
        if (player_hand.size>=3) and (dealer_hand.size>=3):
            print("Acá ya se comienza a jugar la mano individual")
            while (np.sum(dealer_hand)<17):
                card = int(shoe[0])
                print(f"La carta que acaba de salir es: {int(shoe[0])}")
                dealer_hand=np.append(dealer_hand, shoe[0])
                print(f"El dealer hand es de: {dealer_hand}")
                shoe = np.delete(shoe,0)                
                print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print("Termina el turno del dealer")
            print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print(f"El player suma un total de {np.sum(player_hand)}")                      
            if (np.sum(dealer_hand)==21) and (np.sum(player_hand)!=21):
                print("**Blackjack para el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            elif (np.sum(dealer_hand) > np.sum(player_hand)) and (np.sum(dealer_hand)<21):
                print("**Gano el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            elif (np.sum(dealer_hand) == np.sum(player_hand)):
                print("Empate")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            elif (np.sum(player_hand)==21) and (np.sum(dealer_hand)!=21):
                print("**Blackjack para el player**")
                profit_dealer-=1.5
                profit_player+=1.5
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            elif (np.sum(dealer_hand) < np.sum(player_hand)) and (np.sum(player_hand)<21):
                print("**Gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            elif (np.sum(dealer_hand) > 21) and (np.sum(player_hand)<21):
                print("**Dealer bust, gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
            print(shoe)
        #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
          
    else:
        print("¡Se acabó el shoe!")
        print(f"La ganancia total en este shoe para el player es de: {profit_player}")
    return True

blackjack_game(1)
# Out:
# [10  6 10  1  5  7  8 10  7 10  5 10 10  3 10  5 10  4  8 10 10  6  4  1
#  10  3  6  2  4  9  3 10  1 10 10  8  7  6  9  2  2  4  9  9 10  3  5  1
#  10  2  7  8]
# ********************************************
# El shoe tiene: 52 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 6]
# ********************************************
# El shoe tiene: 50 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10 10]
# La carta que acaba de salir es: 1
# El dealer hand es de: [0 6 1]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 5
# El dealer hand es de: [0 6 1 5]
# El dealer suma un total de 12
# La carta que acaba de salir es: 7
# El dealer hand es de: [0 6 1 5 7]
# El dealer suma un total de 19
# Termina el turno del dealer
# El dealer suma un total de 19
# El player suma un total de 20
# **Gano el player**
# [ 8 10  7 10  5 10 10  3 10  5 10  4  8 10 10  6  4  1 10  3  6  2  4  9
#   3 10  1 10 10  8  7  6  9  2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 46 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 8]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 44 cartas
# La carta que acaba de salir es: 7
# El player hand es de: [0 8 7]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10 10]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 15
# **Gano el dealer**
# [ 5 10 10  3 10  5 10  4  8 10 10  6  4  1 10  3  6  2  4  9  3 10  1 10
#  10  8  7  6  9  2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 42 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [0 5]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 40 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0  5 10]
# La carta que acaba de salir es: 3
# El dealer hand es de: [ 0 10  3]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10  3 10]
# El dealer suma un total de 23
# Termina el turno del dealer
# El dealer suma un total de 23
# El player suma un total de 15
# **Dealer bust, gano el player**
# [ 5 10  4  8 10 10  6  4  1 10  3  6  2  4  9  3 10  1 10 10  8  7  6  9
#   2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 37 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [0 5]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 35 cartas
# La carta que acaba de salir es: 4
# El player hand es de: [0 5 4]
# La carta que acaba de salir es: 8
# El dealer hand es de: [ 0 10  8]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 18
# El player suma un total de 9
# **Gano el dealer**
# [10 10  6  4  1 10  3  6  2  4  9  3 10  1 10 10  8  7  6  9  2  2  4  9
#   9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 33 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 31 cartas
# La carta que acaba de salir es: 6
# El player hand es de: [ 0 10  6]
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0 10  4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 1
# El dealer hand es de: [ 0 10  4  1]
# El dealer suma un total de 15
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10  4  1 10]
# El dealer suma un total de 25
# Termina el turno del dealer
# El dealer suma un total de 25
# El player suma un total de 16
# **Dealer bust, gano el player**
# [ 3  6  2  4  9  3 10  1 10 10  8  7  6  9  2  2  4  9  9 10  3  5  1 10
#   2  7  8]
# ********************************************
# El shoe tiene: 27 cartas
# La carta que acaba de salir es: 3
# El player hand es de: [0 3]
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 6]
# ********************************************
# El shoe tiene: 25 cartas
# La carta que acaba de salir es: 2
# El player hand es de: [0 3 2]
# La carta que acaba de salir es: 4
# El dealer hand es de: [0 6 4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 6 4 9]
# El dealer suma un total de 19
# Termina el turno del dealer
# El dealer suma un total de 19
# El player suma un total de 5
# **Gano el dealer**
# [ 3 10  1 10 10  8  7  6  9  2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 22 cartas
# La carta que acaba de salir es: 3
# El player hand es de: [0 3]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 20 cartas
# La carta que acaba de salir es: 1
# El player hand es de: [0 3 1]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10 10]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 4
# **Gano el dealer**
# [10  8  7  6  9  2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 18 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 8
# El dealer hand es de: [0 8]
# ********************************************
# El shoe tiene: 16 cartas
# La carta que acaba de salir es: 7
# El player hand es de: [ 0 10  7]
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 8 6]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 8 6 9]
# El dealer suma un total de 23
# Termina el turno del dealer
# El dealer suma un total de 23
# El player suma un total de 17
# **Dealer bust, gano el player**
# [ 2  2  4  9  9 10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 13 cartas
# La carta que acaba de salir es: 2
# El player hand es de: [0 2]
# La carta que acaba de salir es: 2
# El dealer hand es de: [0 2]
# ********************************************
# El shoe tiene: 11 cartas
# La carta que acaba de salir es: 4
# El player hand es de: [0 2 4]
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 2 9]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 2 9 9]
# El dealer suma un total de 20
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 6
# **Gano el dealer**
# [10  3  5  1 10  2  7  8]
# ********************************************
# El shoe tiene: 8 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3]
# ********************************************
# El shoe tiene: 6 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [ 0 10  5]
# La carta que acaba de salir es: 1
# El dealer hand es de: [0 3 1]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  3  1 10]
# El dealer suma un total de 14
# La carta que acaba de salir es: 2
# El dealer hand es de: [ 0  3  1 10  2]
# El dealer suma un total de 16
# La carta que acaba de salir es: 7
# El dealer hand es de: [ 0  3  1 10  2  7]
# El dealer suma un total de 23
# Termina el turno del dealer
# El dealer suma un total de 23
# El player suma un total de 15
# **Dealer bust, gano el player**
# [8]
# ¡Se acabó el shoe!
# La ganancia total en este shoe para el player es de: 0
# True

# %% [markdown]
# ## COMPILA 2

# %%
def blackjack_game(decks:int, players=1):    
    
    profit_dealer=0
    profit_player=0
    shoe=np.full(decks*4,1)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    print(shoe)
    player_first_cards = np.full(1,0)
    dealer_first_cards = np.full(1,0)
    hand_result=np.full(1,"NA")
    while (shoe.size>5):
        print("********************************************")
        print(f"El shoe tiene: {shoe.size} cartas")
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {int(shoe[0])}")
        #Se le da las 2 cartas inciales al jugador
        if (player_hand.size<=2):
            player_hand=np.append(player_hand, shoe[0])
        print(f"El player hand es de: {player_hand}")
        shoe = np.delete(shoe,0)        
        
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {card}")
        #Se le da las 2 cartas iniciales al dealer
        if (dealer_hand.size<=2):
            dealer_hand=np.append(dealer_hand, shoe[0])
        print(f"El dealer hand es de: {dealer_hand}")
        shoe = np.delete(shoe,0)
        #ee   
        
        if (player_hand.size>=3) and (dealer_hand.size>=3):
            print("Acá ya se comienza a jugar la mano individual")
            while (np.sum(dealer_hand)<17):
                card = int(shoe[0])
                print(f"La carta que acaba de salir es: {int(shoe[0])}")
                dealer_hand=np.append(dealer_hand, shoe[0])
                print(f"El dealer hand es de: {dealer_hand}")
                shoe = np.delete(shoe,0)                
                print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print("Termina el turno del dealer")
            print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print(f"El player suma un total de {np.sum(player_hand)}")
            
            if (np.sum(dealer_hand)==21) and (np.sum(player_hand)!=21):
                print("**Blackjack para el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])                
                hand_result=np.append(hand_result, "L")                
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > np.sum(player_hand)) and (np.sum(dealer_hand)<21):
                print("**Gano el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, "L")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) == np.sum(player_hand)):
                print("Empate")
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, "P")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(player_hand)==21) and (np.sum(dealer_hand)!=21):
                print("**Blackjack para el player**")
                profit_dealer-=1.5
                profit_player+=1.5
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, "W")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) < np.sum(player_hand)) and (np.sum(player_hand)<21):
                print("**Gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, "W")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > 21) and (np.sum(player_hand)<21):
                print("**Dealer bust, gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, "W")
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            print(shoe)
        #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
          
    else:
        print("¡Se acabó el shoe!")
        print(f"La ganancia total en este shoe para el player es de: {profit_player}")
    return (player_first_cards, hand_result, dealer_first_cards)

blackjack_game(1)
# Out:
# [ 8  7  9  5  7  2 10  6  6  1  1 10  1 10 10  9  5 10  8  3  7  3 10  9
#   2  6  6 10 10 10 10  4  4  2  4  5  5  8 10  8  3  1  7 10  4  9 10  3
#  10 10 10  2]
# ********************************************
# El shoe tiene: 52 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 8]
# La carta que acaba de salir es: 7
# El dealer hand es de: [0 7]
# ********************************************
# El shoe tiene: 50 cartas
# La carta que acaba de salir es: 9
# El player hand es de: [0 8 9]
# La carta que acaba de salir es: 5
# El dealer hand es de: [0 7 5]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 7
# El dealer hand es de: [0 7 5 7]
# El dealer suma un total de 19
# Termina el turno del dealer
# El dealer suma un total de 19
# El player suma un total de 17
# **Gano el dealer**
# [ 2 10  6  6  1  1 10  1 10 10  9  5 10  8  3  7  3 10  9  2  6  6 10 10
#  10 10  4  4  2  4  5  5  8 10  8  3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 47 cartas
# La carta que acaba de salir es: 2
# El player hand es de: [0 2]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 45 cartas
# La carta que acaba de salir es: 6
# El player hand es de: [0 2 6]
# La carta que acaba de salir es: 6
# El dealer hand es de: [ 0 10  6]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 1
# El dealer hand es de: [ 0 10  6  1]
# El dealer suma un total de 17
# Termina el turno del dealer
# El dealer suma un total de 17
# El player suma un total de 8
# **Gano el dealer**
# [ 1 10  1 10 10  9  5 10  8  3  7  3 10  9  2  6  6 10 10 10 10  4  4  2
#   4  5  5  8 10  8  3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 42 cartas
# La carta que acaba de salir es: 1
# El player hand es de: [0 1]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 40 cartas
# La carta que acaba de salir es: 1
# El player hand es de: [0 1 1]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10 10]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 2
# **Gano el dealer**
# [10  9  5 10  8  3  7  3 10  9  2  6  6 10 10 10 10  4  4  2  4  5  5  8
#  10  8  3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 38 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 9]
# ********************************************
# El shoe tiene: 36 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [ 0 10  5]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  9 10]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 19
# El player suma un total de 15
# **Gano el dealer**
# [ 8  3  7  3 10  9  2  6  6 10 10 10 10  4  4  2  4  5  5  8 10  8  3  1
#   7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 34 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 8]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3]
# ********************************************
# El shoe tiene: 32 cartas
# La carta que acaba de salir es: 7
# El player hand es de: [0 8 7]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3 3]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  3  3 10]
# El dealer suma un total de 16
# La carta que acaba de salir es: 9
# El dealer hand es de: [ 0  3  3 10  9]
# El dealer suma un total de 25
# Termina el turno del dealer
# El dealer suma un total de 25
# El player suma un total de 15
# **Dealer bust, gano el player**
# [ 2  6  6 10 10 10 10  4  4  2  4  5  5  8 10  8  3  1  7 10  4  9 10  3
#  10 10 10  2]
# ********************************************
# El shoe tiene: 28 cartas
# La carta que acaba de salir es: 2
# El player hand es de: [0 2]
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 6]
# ********************************************
# El shoe tiene: 26 cartas
# La carta que acaba de salir es: 6
# El player hand es de: [0 2 6]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  6 10]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  6 10 10]
# El dealer suma un total de 26
# Termina el turno del dealer
# El dealer suma un total de 26
# El player suma un total de 8
# **Dealer bust, gano el player**
# [10 10  4  4  2  4  5  5  8 10  8  3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 23 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 21 cartas
# La carta que acaba de salir es: 4
# El player hand es de: [ 0 10  4]
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0 10  4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 2
# El dealer hand es de: [ 0 10  4  2]
# El dealer suma un total de 16
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0 10  4  2  4]
# El dealer suma un total de 20
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 14
# **Gano el dealer**
# [ 5  5  8 10  8  3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 17 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [0 5]
# La carta que acaba de salir es: 5
# El dealer hand es de: [0 5]
# ********************************************
# El shoe tiene: 15 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 5 8]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  5 10]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 8
# El dealer hand es de: [ 0  5 10  8]
# El dealer suma un total de 23
# Termina el turno del dealer
# El dealer suma un total de 23
# El player suma un total de 13
# **Dealer bust, gano el player**
# [ 3  1  7 10  4  9 10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 12 cartas
# La carta que acaba de salir es: 3
# El player hand es de: [0 3]
# La carta que acaba de salir es: 1
# El dealer hand es de: [0 1]
# ********************************************
# El shoe tiene: 10 cartas
# La carta que acaba de salir es: 7
# El player hand es de: [0 3 7]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  1 10]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0  1 10  4]
# El dealer suma un total de 15
# La carta que acaba de salir es: 9
# El dealer hand es de: [ 0  1 10  4  9]
# El dealer suma un total de 24
# Termina el turno del dealer
# El dealer suma un total de 24
# El player suma un total de 10
# **Dealer bust, gano el player**
# [10  3 10 10 10  2]
# ********************************************
# El shoe tiene: 6 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3]
# ¡Se acabó el shoe!
# La ganancia total en este shoe para el player es de: -1
# (array([ 0, 17,  8,  2, 15, 15,  8, 14, 13, 10]),
#  array(['NA', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W'], dtype='<U2'),
#  array([ 0,  7, 10, 10,  9,  3,  6, 10,  5,  1]))

# %% [markdown]
# ## COMPILA 3

# %%
def blackjack_game(decks:int, players=1):    
    
    profit_dealer=0
    profit_player=0
    shoe=np.full(decks*4,11)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    print(shoe)
    player_first_cards = np.full(1,0)
    dealer_first_cards = np.full(1,0)
    hand_result=np.full(1,0)
    while (shoe.size>5):
        print("********************************************")
        print(f"El shoe tiene: {shoe.size} cartas")
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {int(shoe[0])}")
        #Se le da las 2 cartas inciales al jugador
        if (player_hand.size<=2):
            player_hand=np.append(player_hand, shoe[0])
        print(f"El player hand es de: {player_hand}")
        shoe = np.delete(shoe,0)        
        
        card = int(shoe[0])
        print(f"La carta que acaba de salir es: {card}")
        #Se le da las 2 cartas iniciales al dealer
        if (dealer_hand.size<=2):
            dealer_hand=np.append(dealer_hand, shoe[0])
        print(f"El dealer hand es de: {dealer_hand}")
        shoe = np.delete(shoe,0)
        #ee   
        
        if (player_hand.size>=3) and (dealer_hand.size>=3):
            print("Acá ya se comienza a jugar la mano individual")
            while (np.sum(dealer_hand)<17):
                card = int(shoe[0])
                print(f"La carta que acaba de salir es: {int(shoe[0])}")
                dealer_hand=np.append(dealer_hand, shoe[0])
                print(f"El dealer hand es de: {dealer_hand}")
                shoe = np.delete(shoe,0)                
                print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print("Termina el turno del dealer")
            print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            print(f"El player suma un total de {np.sum(player_hand)}")
            
            if (np.sum(dealer_hand)==21) and (np.sum(player_hand)!=21):
                print("**Blackjack para el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])                
                hand_result=np.append(hand_result, -1)                
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > np.sum(player_hand)) and (np.sum(dealer_hand)<21):
                print("**Gano el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, -1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) == np.sum(player_hand)):
                print("Empate")
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 0)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(player_hand)==21) and (np.sum(dealer_hand)!=21):
                print("**Blackjack para el player**")
                profit_dealer-=1.5
                profit_player+=1.5
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1.5)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) < np.sum(player_hand)) and (np.sum(player_hand)<21):
                print("**Gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > 21) and (np.sum(player_hand)<21):
                print("**Dealer bust, gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            print(shoe)
        #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
          
    else:
        print("¡Se acabó el shoe!")
        print(f"La ganancia total en este shoe para el player es de: {profit_player}")
    
    return (arrays_to_df(player_first_cards, hand_result, dealer_first_cards))

blackjack_game(1)
# Out:
# [10  4  7 10  9  5 10  2  7 10  5  5 10  7  8  9  6  6 10  6 10  8 10 11
#  10 10  4  3 11 11  9 11 10  5 10  4  7  9 10  3  3  3  6 10  8 10 10  4
#   2  2  8  2]
# ********************************************
# El shoe tiene: 52 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 4
# El dealer hand es de: [0 4]
# ********************************************
# El shoe tiene: 50 cartas
# La carta que acaba de salir es: 7
# El player hand es de: [ 0 10  7]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  4 10]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 9
# El dealer hand es de: [ 0  4 10  9]
# El dealer suma un total de 23
# Termina el turno del dealer
# El dealer suma un total de 23
# El player suma un total de 17
# **Dealer bust, gano el player**
# [ 5 10  2  7 10  5  5 10  7  8  9  6  6 10  6 10  8 10 11 10 10  4  3 11
#  11  9 11 10  5 10  4  7  9 10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 47 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [0 5]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 45 cartas
# La carta que acaba de salir es: 2
# El player hand es de: [0 5 2]
# La carta que acaba de salir es: 7
# El dealer hand es de: [ 0 10  7]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 17
# El player suma un total de 7
# **Gano el dealer**
# [10  5  5 10  7  8  9  6  6 10  6 10  8 10 11 10 10  4  3 11 11  9 11 10
#   5 10  4  7  9 10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 43 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 5
# El dealer hand es de: [0 5]
# ********************************************
# El shoe tiene: 41 cartas
# La carta que acaba de salir es: 5
# El player hand es de: [ 0 10  5]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  5 10]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 7
# El dealer hand es de: [ 0  5 10  7]
# El dealer suma un total de 22
# Termina el turno del dealer
# El dealer suma un total de 22
# El player suma un total de 15
# **Dealer bust, gano el player**
# [ 8  9  6  6 10  6 10  8 10 11 10 10  4  3 11 11  9 11 10  5 10  4  7  9
#  10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 38 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 8]
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 9]
# ********************************************
# El shoe tiene: 36 cartas
# La carta que acaba de salir es: 6
# El player hand es de: [0 8 6]
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 9 6]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  9  6 10]
# El dealer suma un total de 25
# Termina el turno del dealer
# El dealer suma un total de 25
# El player suma un total de 14
# **Dealer bust, gano el player**
# [ 6 10  8 10 11 10 10  4  3 11 11  9 11 10  5 10  4  7  9 10  3  3  3  6
#  10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 33 cartas
# La carta que acaba de salir es: 6
# El player hand es de: [0 6]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 31 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 6 8]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10 10]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 20
# El player suma un total de 14
# **Gano el dealer**
# [11 10 10  4  3 11 11  9 11 10  5 10  4  7  9 10  3  3  3  6 10  8 10 10
#   4  2  2  8  2]
# ********************************************
# El shoe tiene: 29 cartas
# La carta que acaba de salir es: 11
# El player hand es de: [ 0 11]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 27 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 11 10]
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0 10  4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 3
# El dealer hand es de: [ 0 10  4  3]
# El dealer suma un total de 17
# Termina el turno del dealer
# El dealer suma un total de 17
# El player suma un total de 21
# **Blackjack para el player**
# [11 11  9 11 10  5 10  4  7  9 10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 24 cartas
# La carta que acaba de salir es: 11
# El player hand es de: [ 0 11]
# La carta que acaba de salir es: 11
# El dealer hand es de: [ 0 11]
# ********************************************
# El shoe tiene: 22 cartas
# La carta que acaba de salir es: 9
# El player hand es de: [ 0 11  9]
# La carta que acaba de salir es: 11
# El dealer hand es de: [ 0 11 11]
# Acá ya se comienza a jugar la mano individual
# Termina el turno del dealer
# El dealer suma un total de 22
# El player suma un total de 20
# **Dealer bust, gano el player**
# [10  5 10  4  7  9 10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 20 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 5
# El dealer hand es de: [0 5]
# ********************************************
# El shoe tiene: 18 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10 10]
# La carta que acaba de salir es: 4
# El dealer hand es de: [0 5 4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 7
# El dealer hand es de: [0 5 4 7]
# El dealer suma un total de 16
# La carta que acaba de salir es: 9
# El dealer hand es de: [0 5 4 7 9]
# El dealer suma un total de 25
# Termina el turno del dealer
# El dealer suma un total de 25
# El player suma un total de 20
# **Dealer bust, gano el player**
# [10  3  3  3  6 10  8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 14 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0 10]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3]
# ********************************************
# El shoe tiene: 12 cartas
# La carta que acaba de salir es: 3
# El player hand es de: [ 0 10  3]
# La carta que acaba de salir es: 3
# El dealer hand es de: [0 3 3]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 6
# El dealer hand es de: [0 3 3 6]
# El dealer suma un total de 12
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0  3  3  6 10]
# El dealer suma un total de 22
# Termina el turno del dealer
# El dealer suma un total de 22
# El player suma un total de 13
# **Dealer bust, gano el player**
# [ 8 10 10  4  2  2  8  2]
# ********************************************
# El shoe tiene: 8 cartas
# La carta que acaba de salir es: 8
# El player hand es de: [0 8]
# La carta que acaba de salir es: 10
# El dealer hand es de: [ 0 10]
# ********************************************
# El shoe tiene: 6 cartas
# La carta que acaba de salir es: 10
# El player hand es de: [ 0  8 10]
# La carta que acaba de salir es: 4
# El dealer hand es de: [ 0 10  4]
# Acá ya se comienza a jugar la mano individual
# La carta que acaba de salir es: 2
# El dealer hand es de: [ 0 10  4  2]
# El dealer suma un total de 16
# La carta que acaba de salir es: 2
# El dealer hand es de: [ 0 10  4  2  2]
# El dealer suma un total de 18
# Termina el turno del dealer
# El dealer suma un total de 18
# El player suma un total de 18
# Empate
# [8 2]
# ¡Se acabó el shoe!
# La ganancia total en este shoe para el player es de: 5.5
#     Hard_Total  Result  Dealer_Upcard
# 0            0     0.0              0
# 1           17     1.0              4
# 2            7    -1.0             10
# 3           15     1.0              5
# 4           14     1.0              9
# 5           14    -1.0             10
# 6           21     1.5             10
# 7           20     1.0             11
# 8           20     1.0              5
# 9           13     1.0              3
# 10          18     0.0             10

# %% [markdown]
# ## COMPILA 4

# %%
def blackjack_game(decks:int, players=1):    
    
    profit_dealer=0
    profit_player=0
    shoe=np.full(decks*4,11)
    two=np.full(decks*4,2)
    three=np.full(decks*4,3)
    four=np.full(decks*4,4)
    five=np.full(decks*4,5)
    six=np.full(decks*4,6)
    seven=np.full(decks*4,7)
    eight=np.full(decks*4,8)
    nine=np.full(decks*4,9)
    ten=np.full(decks*4,10)
    j=np.full(decks*4,10)
    q=np.full(decks*4,10)
    k=np.full(decks*4,10)
    total_faces=(two, three, four, five, six, seven, eight, nine, ten, j, q, k)
    for i in total_faces:
        shoe = np.hstack((shoe,i))
    np.random.shuffle(shoe)
    player_hand=np.full(1,0)
    dealer_hand=np.full(1,0)
    #print(shoe)
    player_first_cards = np.full(1,0)
    dealer_first_cards = np.full(1,0)
    hand_result=np.full(1,0)
    while (shoe.size>5):
        #print("********************************************")
        #print(f"El shoe tiene: {shoe.size} cartas")
        card = int(shoe[0])
        #print(f"La carta que acaba de salir es: {int(shoe[0])}")
        #Se le da las 2 cartas inciales al jugador
        if (player_hand.size<=2):
            player_hand=np.append(player_hand, shoe[0])
        #print(f"El player hand es de: {player_hand}")
        shoe = np.delete(shoe,0)        
        
        card = int(shoe[0])
        #print(f"La carta que acaba de salir es: {card}")
        #Se le da las 2 cartas iniciales al dealer
        if (dealer_hand.size<=2):
            dealer_hand=np.append(dealer_hand, shoe[0])
        #print(f"El dealer hand es de: {dealer_hand}")
        shoe = np.delete(shoe,0) 
        
        if (player_hand.size>=3) and (dealer_hand.size>=3):
            #print("Acá ya se comienza a jugar la mano individual")
            while (np.sum(dealer_hand)<17):
                card = int(shoe[0])
                #print(f"La carta que acaba de salir es: {int(shoe[0])}")
                dealer_hand=np.append(dealer_hand, shoe[0])
                #print(f"El dealer hand es de: {dealer_hand}")
                shoe = np.delete(shoe,0)                
                #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            #print("Termina el turno del dealer")
            #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
            #print(f"El player suma un total de {np.sum(player_hand)}")
            
            if (np.sum(dealer_hand)==21) and (np.sum(player_hand)!=21):
                #print("**Blackjack para el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])                
                hand_result=np.append(hand_result, -1)                
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > np.sum(player_hand)) and (np.sum(dealer_hand)<21):
                #print("**Gano el dealer**")
                profit_dealer+=1
                profit_player-=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, -1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) == np.sum(player_hand)):
                #print("Empate")
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 0)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(player_hand)==21) and (np.sum(dealer_hand)!=21):
                #print("**Blackjack para el player**")
                profit_dealer-=1.5
                profit_player+=1.5
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1.5)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) < np.sum(player_hand)) and (np.sum(player_hand)<21):
                #print("**Gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            elif (np.sum(dealer_hand) > 21) and (np.sum(player_hand)<21):
                #print("**Dealer bust, gano el player**")
                profit_dealer-=1
                profit_player+=1
                player_first_cards=np.append(player_first_cards,np.sum(player_hand))
                dealer_first_cards=np.append(dealer_first_cards, dealer_hand[1])
                hand_result=np.append(hand_result, 1)
                player_hand=np.full(1,0)
                dealer_hand=np.full(1,0)
                
                
            #print(shoe)
        #print(f"El dealer suma un total de {np.sum(dealer_hand)}")
          
    else:
        pass
        #print("¡Se acabó el shoe!")
        #print(f"La ganancia total en este shoe para el player es de: {profit_player}")
    
    return (arrays_to_df(player_first_cards, hand_result, dealer_first_cards))

blackjack_game(1)
# Out:
#     Hard_Total  Result  Dealer_Upcard
# 0            0       0              0
# 1           16      -1             11
# 2           20       0             10
# 3           12      -1              8
# 4           13      -1              2
# 5           19       1              4
# 6           13       1              8
# 7            9      -1             11
# 8           10      -1              9
# 9           20      -1             10
# 10           9       1              7

# %% [markdown]
# ## FUNCIÓN QUE CONVIERTE LOS RESULTADOS DE 3 NDARRAYS A 1 DATA FRAME

# %%
def arrays_to_df(pfh:np.ndarray, res:np.ndarray, dfh:np.ndarray):
    s_pfh=pd.Series(pfh)
    s_res=pd.Series(res)
    s_dfh=pd.Series(dfh)
    basic_strategy_stand = pd.DataFrame({'Hard_Total':s_pfh, 'Result':s_res, 'Dealer_Upcard':s_dfh})
    return basic_strategy_stand

# %%
a = np.array([5,8,9])
b = np.array(["L","W","L"])
c = np.array([10,5,18])

arrays_to_df(a,b,c)
# Out:
#    Hard_Total Result  Dealer_Upcard
# 0           5      L             10
# 1           8      W              5
# 2           9      L             18

# %% [markdown]
# ## EXPERIMENTO MONTE CARLO DEL BLACKJACK

# %%
def monte_carlo_blackjack(n:int, N:int):
    Basic_Strategy = pd.DataFrame()
    for _ in range(N):
        BJiteration = blackjack_game(n)
        Basic_Strategy=pd.concat([Basic_Strategy,BJiteration], ignore_index=True)
    Basic_Strategy = Basic_Strategy.iloc[1:,:]
    return Basic_Strategy

# %%
BJT = monte_carlo_blackjack(6,500)
BJT
# Out:
#        Hard_Total  Result  Dealer_Upcard
# 1               8     1.0              5
# 2              20     1.0              8
# 3              20     1.0              3
# 4              17    -1.0             10
# 5              14     1.0             10
# ...           ...     ...            ...
# 27861          20     1.0             10
# 27862          17    -1.0             10
# 27863          17     1.0              4
# 27864          12    -1.0              8
# 27865          15    -1.0              9
#
# [27865 rows x 3 columns]

# %%
Gamblers_Strategy = BJT.pivot_table(index="Hard_Total",columns="Dealer_Upcard").iloc[1:19,1:]
Gamblers_Strategy
# Out:
#                  Result                                                    \
# Dealer_Upcard        2         3         4         5         6         7
# Hard_Total
# 4             -0.333333 -0.076923 -0.555556 -0.111111 -0.200000 -0.272727
# 5              0.157895 -0.066667 -0.200000 -0.125000 -0.304348 -0.300000
# 6             -0.350000 -0.255814 -0.318182 -0.058824  0.103448 -0.212121
# 7             -0.017544 -0.414634 -0.054545 -0.024390 -0.050847 -0.333333
# 8             -0.214286 -0.169811  0.064935 -0.333333 -0.156250 -0.322034
# 9             -0.041096 -0.064935 -0.043478 -0.116883 -0.234043 -0.425287
# 10            -0.095238 -0.026316 -0.011765 -0.054054  0.023256 -0.605634
# 11            -0.212121 -0.184466 -0.115044 -0.125000 -0.092784 -0.421488
# 12            -0.197605 -0.241758 -0.166667 -0.152174 -0.113636 -0.380000
# 13            -0.307317 -0.072464 -0.121339 -0.023923 -0.026455 -0.306122
# 14            -0.093023 -0.144444 -0.027624  0.103093 -0.096774 -0.510417
# 15            -0.245902 -0.168675 -0.136364 -0.068063 -0.004878 -0.380952
# 16            -0.208556 -0.111111 -0.096386 -0.316129 -0.225806 -0.443038
# 17            -0.178808 -0.093960  0.071895 -0.104651  0.084967 -0.051095
# 18             0.133858  0.349206  0.301775  0.287770  0.289474  0.330645
# 19             0.434109  0.457627  0.400000  0.488550  0.479675  0.581395
# 20             0.683036  0.660377  0.660377  0.698198  0.717949  0.820175
# 21             1.283898  1.368132  1.359813  1.384615  1.400943  1.370192
#
#
# Dealer_Upcard        8         9         10        11
# Hard_Total
# 4             -0.692308 -0.692308 -0.680000 -0.733333
# 5             -0.785714 -0.666667 -0.550000 -0.419355
# 6             -0.459459 -0.476190 -0.566434 -0.470588
# 7             -0.370370 -0.490909 -0.615023 -0.586207
# 8             -0.516129 -0.469388 -0.582677 -0.569231
# 9             -0.582090 -0.462687 -0.551839 -0.674419
# 10            -0.295775 -0.458824 -0.551724 -0.382979
# 11            -0.513043 -0.367347 -0.554987 -0.561404
# 12            -0.620690 -0.436782 -0.506596 -0.469388
# 13            -0.500000 -0.555556 -0.486216 -0.470588
# 14            -0.417989 -0.491713 -0.517881 -0.450777
# 15            -0.373626 -0.537500 -0.547619 -0.607143
# 16            -0.518717 -0.433735 -0.538705 -0.502825
# 17            -0.429630 -0.397059 -0.403813 -0.366197
# 18             0.129252 -0.223077 -0.227357 -0.224000
# 19             0.592920  0.342342  0.000000 -0.015038
# 20             0.808333  0.746835  0.460067  0.309237
# 21             1.415888  1.410256  1.365207  1.008850

# %%
Gamblers_Strategy.to_csv('GamblersStrategy.csv')
